# %% [markdown]
# ##Pokemon CLassification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/pokemonclassification.zip"

# %%
import PIL
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
batch_size = 64
img_height = 124
img_width = 124

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  "/content/PokemonData",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6820 files belonging to 150 classes.
# Using 5456 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  "/content/PokemonData",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6820 files belonging to 150 classes.
# Using 1364 files for validation.

# %%
class_names = train_ds.class_names
num_classes =len(class_names)
print(class_names)
# Out:
# ['Abra', 'Aerodactyl', 'Alakazam', 'Alolan Sandslash', 'Arbok', 'Arcanine', 'Articuno', 'Beedrill', 'Bellsprout', 'Blastoise', 'Bulbasaur', 'Butterfree', 'Caterpie', 'Chansey', 'Charizard', 'Charmander', 'Charmeleon', 'Clefable', 'Clefairy', 'Cloyster', 'Cubone', 'Dewgong', 'Diglett', 'Ditto', 'Dodrio', 'Doduo', 'Dragonair', 'Dragonite', 'Dratini', 'Drowzee', 'Dugtrio', 'Eevee', 'Ekans', 'Electabuzz', 'Electrode', 'Exeggcute', 'Exeggutor', 'Farfetchd', 'Fearow', 'Flareon', 'Gastly', 'Gengar', 'Geodude', 'Gloom', 'Golbat', 'Goldeen', 'Golduck', 'Golem', 'Graveler', 'Grimer', 'Growlithe', 'Gyarados', 'Haunter', 'Hitmonchan', 'Hitmonlee', 'Horsea', 'Hypno', 'Ivysaur', 'Jigglypuff', 'Jolteon', 'Jynx', 'Kabuto', 'Kabutops', 'Kadabra', 'Kakuna', 'Kangaskhan', 'Kingler', 'Koffing', 'Krabby', 'Lapras', 'Lickitung', 'Machamp', 'Machoke', 'Machop', 'Magikarp', 'Magmar', 'Magnemite', 'Magneton', 'Mankey', 'Marowak', 'Meowth', 'Metapod', 'Mew', 'Mewtwo', 'Moltres', 'MrMime', 'Muk', 'Nidoking', '
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(1000, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("model_pokemon.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose = 1)

earlystop = EarlyStopping(monitor="val_loss",
                         min_delta=0,
                         patience=3,
                         verbose=1,
                         restore_best_weights=True)

callbacks = [earlystop, checkpoint]

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 86/86 [==============================] - 125s 1s/step - loss: 4.8975 - accuracy: 0.0154 - val_loss: 4.1492 - val_accuracy: 0.0740
#
# Epoch 00001: val_loss improved from inf to 4.14923, saving model to model_pokemon.h5
# Epoch 2/50
# 86/86 [==============================] - 105s 1s/step - loss: 3.9201 - accuracy: 0.0920 - val_loss: 3.3979 - val_accuracy: 0.1804
#
# Epoch 00002: val_loss improved from 4.14923 to 3.39786, saving model to model_pokemon.h5
# Epoch 3/50
# 86/86 [==============================] - 104s 1s/step - loss: 3.0071 - accuracy: 0.2521 - val_loss: 2.6954 - val_accuracy: 0.3255
#
# Epoch 00003: val_loss improved from 3.39786 to 2.69544, saving model to model_pokemon.h5
# Epoch 4/50
# 86/86 [==============================] - 105s 1s/step - loss: 2.3859 - accuracy: 0.3680 - val_loss: 2.4134 - val_accuracy: 0.3820
#
# Epoch 00004: val_loss improved from 2.69544 to 2.41344, saving model to model_pokemon.h5
# Epoch 5/50
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
class_names
# Out:
# ['Abra',
#  'Aerodactyl',
#  'Alakazam',
#  'Alolan Sandslash',
#  'Arbok',
#  'Arcanine',
#  'Articuno',
#  'Beedrill',
#  'Bellsprout',
#  'Blastoise',
#  'Bulbasaur',
#  'Butterfree',
#  'Caterpie',
#  'Chansey',
#  'Charizard',
#  'Charmander',
#  'Charmeleon',
#  'Clefable',
#  'Clefairy',
#  'Cloyster',
#  'Cubone',
#  'Dewgong',
#  'Diglett',
#  'Ditto',
#  'Dodrio',
#  'Doduo',
#  'Dragonair',
#  'Dragonite',
#  'Dratini',
#  'Drowzee',
#  'Dugtrio',
#  'Eevee',
#  'Ekans',
#  'Electabuzz',
#  'Electrode',
#  'Exeggcute',
#  'Exeggutor',
#  'Farfetchd',
#  'Fearow',
#  'Flareon',
#  'Gastly',
#  'Gengar',
#  'Geodude',
#  'Gloom',
#  'Golbat',
#  'Goldeen',
#  'Golduck',
#  'Golem',
#  'Graveler',
#  'Grimer',
#  'Growlithe',
#  'Gyarados',
#  'Haunter',
#  'Hitmonchan',
#  'Hitmonlee',
#  'Horsea',
#  'Hypno',
#  'Ivysaur',
#  'Jigglypuff',
#  'Jolteon',
#  'Jynx',
#  'Kabuto',
#  'Kabutops',
#  'Kadabra',
#  'Kakuna',
#  'Kangaskhan',
#  'Kingler',
#  'Koffing',
# ...

# %%
image_url = "http://static.pokemonpets.com/images/monsters-images-800-800/11-Metapod.png"
image_name = image_url.split("/")[-1]
image_path = tf.keras.utils.get_file(image_name, origin=image_url)

img = keras.preprocessing.image.load_img(
    image_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ...
# 122880/118468 [===============================] - 0s 1us/step
# This image most likely belongs to Metapod with a 88.71 percent confidence.

# %%
image_url = "https://static.pokemonpets.com/images/monsters-images-300-300/27-Sandshrew.png"
image_name = image_url.split("/")[-1]
image_path = tf.keras.utils.get_file(image_name, origin=image_url)

img = keras.preprocessing.image.load_img(
    image_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ...
# 81920/79366 [==============================] - 0s 1us/step
# This image most likely belongs to Sandshrew with a 85.58 percent confidence.

# %%
image_url = "https://i.pinimg.com/originals/fe/46/ce/fe46ce89c15bbc60688b0a0e000f1d41.png"
image_name = image_url.split("/")[-1]
image_path = tf.keras.utils.get_file(image_name, origin=image_url)

img = keras.preprocessing.image.load_img(
    image_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ...
# 90112/86773 [===============================] - 0s 0us/step
# This image most likely belongs to Spearow with a 99.17 percent confidence.

# %%
image_url = "https://i.pinimg.com/originals/8e/73/d2/8e73d250ceb3993b111b8e9b50f6c58f.png"
image_name = image_url.split("/")[-1]
image_path = tf.keras.utils.get_file(image_name, origin=image_url)

img = keras.preprocessing.image.load_img(
    image_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ...
# 57344/51454 [=================================] - 0s 0us/step
# This image most likely belongs to Wartortle with a 99.91 percent confidence.

# %%
image_url = "http://static.pokemonpets.com/images/monsters-images-800-800/73-Tentacruel.png"
image_name = image_url.split("/")[-1]
image_path = tf.keras.utils.get_file(image_name, origin=image_url)

img = keras.preprocessing.image.load_img(
    image_path, target_size=(img_height, img_width)
)
plt.imshow(img)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# ...
# 278528/275046 [==============================] - 0s 1us/step
# This image most likely belongs to Tentacruel with a 99.95 percent confidence.

# %%
# !cp "/content/model_pokemon.h5" "/content/drive/MyDrive"
